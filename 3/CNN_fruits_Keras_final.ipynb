# %% [markdown]
# ## Data Preparation
#
# Dataset source: http://www.vicos.si/Downloads/FIDS30

# %%
# importing os module 
import os 

# TODO - Set the path to original dataset folder
original_dataset_path = 'C:/DataSets/FIDS30/'
for subdir in os.listdir(original_dataset_path):
    print(subdir)
# Out:
# acerolas
# apples
# apricots
# avocados
# bananas
# blackberries
# blueberries
# cantaloupes
# cherries
# coconuts
# figs
# fruits.txt
# grapefruits
# grapes
# guava
# kiwifruit
# lemons
# limes
# links.txt
# mangos
# olives
# oranges
# passionfruit
# peaches
# pears
# pineapples
# plums
# pomegranates
# raspberries
# strawberries
# tomatoes
# watermelons

# %%
acerolas_folder = original_dataset_path + 'acerolas/'
for filename in os.listdir(acerolas_folder):
    print(filename)
# Out:
# 1.jpg
# 10.jpg
# 12.jpg
# 15.jpg
# 16.jpg
# 18.jpg
# 19.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 25.jpg
# 29.jpg
# 3.jpg
# 30.jpg
# 33.jpg
# 34.jpg
# 35.jpg
# 36.jpg
# 38.jpg
# 39.jpg
# 43.jpg
# 44.jpg
# 46.jpg
# 5.jpg

# %% [markdown]
# ### Pre-Process Photos into Standard Directories
#
# This API prefers data to be divided into separate train/ and test/ directories, and under each directory to have a subdirectory for each class, e.g. a train/acerolas/ and a train/apples/ etc., subdirectories and the same for test. Images are then organized under the subdirectories.
#
# Alternately, we can load the images progressively using the Keras ImageDataGenerator class and flow_from_directory() API.
# This will be slower to execute but will run on more machines.
#
# We can write a script to create a copy of the dataset with this preferred structure.
# We will randomly select 20% of the images to be used in a test dataset.
#
# First, we need to create the directory structure as follows:

# %% [raw]
# Dataset folder structure:
#
# dataset_folder
# ├── test_folder
# │   ├── class_1_folder
# │   └── class_x_folder
# └── train_folder
#     ├── class_1_folder
#     └── class_x_folder

# %% [markdown]
# - Create a new dataset folder;
# - Create train and test directories into the new dataset folder;
# - Rename all the files from original dataset directories to have class name included;
# - Copy all files from all subdirectories of the original dataset folder into the new dataset folder;
# - Copy all image files from the new dataset folder into train/test class subdirectories;

# %% [markdown]
# ### Organize the Dataset to have the above structure
#
# Create a new dataset folder which will contain all renaming images from the original dataset folder.

# %%
# define the name of the directory to be created
# TODO - Set the path to new dataset folder
new_dataset_path = "C:/DataSets/FIDS30_30_Classes/"
try:
    os.mkdir(new_dataset_path)
except OSError:
    print ("Creation of the directory %s failed" % new_dataset_path)
else:
    print ("Successfully created the directory %s " % new_dataset_path)
# Out:
# Successfully created the directory C:/DataSets/FIDS30_30_Classes/

# %% [markdown]
# ### Create train and test directories into new dataset folder

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# organize dataset into a useful structure
# create train and test directories
subdirs = ['train/', 'test/']
for subdir in subdirs:
    # create label subdirectories                                                                                                                                                                                                                                                                                                   
    labeldirs = ['acerolas/', 'apples/', 'apricots/', 'avocados/', 'bananas/', 'blackberries/', 'blueberries/', 'cantaloupes/', 'cherries/', 'coconuts/', 'figs/', 'grapefruits/', 'grapes/', 'guava/', 'kiwifruit/', 'lemons/', 'limes/', 'mangos/', 'olives/', 'oranges/', 'passionfruit/', 'peaches/', 'pears/', 'pineapples/', 'plums/', 'pomegranates/', 'raspberries/', 'strawberries/', 'tomatoes/', 'watermelons/']
    for labldir in labeldirs:
        newdir = new_dataset_path + subdir + labldir
        os.makedirs(newdir, exist_ok=True)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Rename files into original dataset subdirectories
#
# Syntax for os.rename() :
#
# - os.rename(src, dst) : src is source address of file to be renamed and dst is destination with the new name.
#
# The listdir method lists out all the content of a given directory. Syntax for listdir() :
#
# - list = os.listdir(‘Src’) : Where Src is the source to be listed out.

# %%
labeldirs = ['acerolas/', 'apples/', 'apricots/', 'avocados/', 'bananas/', 'blackberries/', 'blueberries/', 'cantaloupes/', 'cherries/', 'coconuts/', 'figs/', 'grapefruits/', 'grapes/', 'guava/', 'kiwifruit/', 'lemons/', 'limes/', 'mangos/', 'olives/', 'oranges/', 'passionfruit/', 'peaches/', 'pears/', 'pineapples/', 'plums/', 'pomegranates/', 'raspberries/', 'strawberries/', 'tomatoes/', 'watermelons/']

# %%
# importing os module 
import os 

acerolas_src_folder = original_dataset_path + labeldirs[0]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(acerolas_src_folder): 
        dst = "acerolas" + "." + str(i) + ".jpg"
        src = acerolas_src_folder + filename 
        dst = acerolas_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

apples_src_folder = original_dataset_path + labeldirs[1]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(apples_src_folder): 
        dst = "apples" + "." + str(i) + ".jpg"
        src = apples_src_folder + filename 
        dst = apples_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

apricots_src_folder = original_dataset_path + labeldirs[2]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(apricots_src_folder): 
        dst = "apricots" + "." + str(i) + ".jpg"
        src = apricots_src_folder + filename 
        dst = apricots_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

avocados_src_folder = original_dataset_path + labeldirs[3]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(avocados_src_folder): 
        dst = "avocados" + "." + str(i) + ".jpg"
        src = avocados_src_folder + filename 
        dst = avocados_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

bananas_src_folder = original_dataset_path + labeldirs[4]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(bananas_src_folder): 
        dst = "bananas" + "." + str(i) + ".jpg"
        src = bananas_src_folder + filename 
        dst = bananas_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

blackberries_src_folder = original_dataset_path + labeldirs[5]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(blackberries_src_folder): 
        dst = "blackberries" + "." + str(i) + ".jpg"
        src = blackberries_src_folder + filename 
        dst = blackberries_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

blueberries_src_folder = original_dataset_path + labeldirs[6]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(blueberries_src_folder): 
        dst = "blueberries" + "." + str(i) + ".jpg"
        src = blueberries_src_folder + filename 
        dst = blueberries_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

cantaloupes_src_folder = original_dataset_path + labeldirs[7]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(cantaloupes_src_folder): 
        dst = "cantaloupes" + "." + str(i) + ".jpg"
        src = cantaloupes_src_folder + filename 
        dst = cantaloupes_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

cherries_src_folder = original_dataset_path + labeldirs[8]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(cherries_src_folder): 
        dst = "cherries" + "." + str(i) + ".jpg"
        src = cherries_src_folder + filename 
        dst = cherries_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

coconuts_src_folder = original_dataset_path + labeldirs[9]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(coconuts_src_folder): 
        dst = "coconuts" + "." + str(i) + ".jpg"
        src = coconuts_src_folder + filename 
        dst = coconuts_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

figs_src_folder = original_dataset_path + labeldirs[10]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(figs_src_folder): 
        dst = "figs" + "." + str(i) + ".jpg"
        src = figs_src_folder + filename 
        dst = figs_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

grapefruits_src_folder = original_dataset_path + labeldirs[11]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(grapefruits_src_folder): 
        dst = "grapefruits" + "." + str(i) + ".jpg"
        src = grapefruits_src_folder + filename 
        dst = grapefruits_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

grapes_src_folder = original_dataset_path + labeldirs[12]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(grapes_src_folder): 
        dst = "grapes" + "." + str(i) + ".jpg"
        src = grapes_src_folder + filename 
        dst = grapes_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

guava_src_folder = original_dataset_path + labeldirs[13]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(guava_src_folder): 
        dst = "guava" + "." + str(i) + ".jpg"
        src = guava_src_folder + filename 
        dst = guava_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

kiwifruit_src_folder = original_dataset_path + labeldirs[14]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(kiwifruit_src_folder): 
        dst = "kiwifruit" + "." + str(i) + ".jpg"
        src = kiwifruit_src_folder + filename 
        dst = kiwifruit_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

lemons_src_folder = original_dataset_path + labeldirs[15]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(lemons_src_folder): 
        dst = "lemons" + "." + str(i) + ".jpg"
        src = lemons_src_folder + filename 
        dst = lemons_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

limes_src_folder = original_dataset_path + labeldirs[16]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(limes_src_folder): 
        dst = "limes" + "." + str(i) + ".jpg"
        src = limes_src_folder + filename 
        dst = limes_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

mangos_src_folder = original_dataset_path + labeldirs[17]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(mangos_src_folder): 
        dst = "mangos" + "." + str(i) + ".jpg"
        src = mangos_src_folder + filename 
        dst = mangos_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

olives_src_folder = original_dataset_path + labeldirs[18]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(olives_src_folder): 
        dst = "olives" + "." + str(i) + ".jpg"
        src = olives_src_folder + filename 
        dst = olives_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

oranges_src_folder = original_dataset_path + labeldirs[19]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(oranges_src_folder): 
        dst = "oranges" + "." + str(i) + ".jpg"
        src = oranges_src_folder + filename 
        dst = oranges_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

passionfruit_src_folder = original_dataset_path + labeldirs[20]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(passionfruit_src_folder): 
        dst = "passionfruit" + "." + str(i) + ".jpg"
        src = passionfruit_src_folder + filename 
        dst = passionfruit_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

peaches_src_folder = original_dataset_path + labeldirs[21]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(peaches_src_folder): 
        dst = "peaches" + "." + str(i) + ".jpg"
        src = peaches_src_folder + filename 
        dst = peaches_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

pears_src_folder = original_dataset_path + labeldirs[22]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(pears_src_folder): 
        dst = "pears" + "." + str(i) + ".jpg"
        src = pears_src_folder + filename 
        dst = pears_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

pineapples_src_folder = original_dataset_path + labeldirs[23]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(pineapples_src_folder): 
        dst = "pineapples" + "." + str(i) + ".jpg"
        src = pineapples_src_folder + filename 
        dst = pineapples_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

plums_src_folder = original_dataset_path + labeldirs[24]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(plums_src_folder): 
        dst = "plums" + "." + str(i) + ".jpg"
        src = plums_src_folder + filename 
        dst = plums_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

pomegranates_src_folder = original_dataset_path + labeldirs[25]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(pomegranates_src_folder): 
        dst = "pomegranates" + "." + str(i) + ".jpg"
        src = pomegranates_src_folder + filename 
        dst = pomegranates_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

raspberries_src_folder = original_dataset_path + labeldirs[26]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(raspberries_src_folder): 
        dst = "raspberries" + "." + str(i) + ".jpg"
        src = raspberries_src_folder + filename 
        dst = raspberries_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

strawberries_src_folder = original_dataset_path + labeldirs[27]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(strawberries_src_folder): 
        dst = "strawberries" + "." + str(i) + ".jpg"
        src = strawberries_src_folder + filename 
        dst = strawberries_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

tomatoes_src_folder = original_dataset_path + labeldirs[28]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(tomatoes_src_folder): 
        dst = "tomatoes" + "." + str(i) + ".jpg"
        src = tomatoes_src_folder + filename 
        dst = tomatoes_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %%
# importing os module 
import os 

watermelons_src_folder = original_dataset_path + labeldirs[29]

# Function to rename multiple files 
def rename_files(): 
    i = 0
      
    for filename in os.listdir(watermelons_src_folder): 
        dst = "watermelons" + "." + str(i) + ".jpg"
        src = watermelons_src_folder + filename 
        dst = watermelons_src_folder + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
        i += 1
        
rename_files()

# %% [markdown]
# ### End of renaming files

# %%
src_directorys = [acerolas_src_folder, apples_src_folder, apricots_src_folder, avocados_src_folder, bananas_src_folder, blackberries_src_folder, blueberries_src_folder, cantaloupes_src_folder, cherries_src_folder, coconuts_src_folder, figs_src_folder, grapefruits_src_folder, grapes_src_folder, guava_src_folder, kiwifruit_src_folder, lemons_src_folder, limes_src_folder, mangos_src_folder, olives_src_folder, oranges_src_folder, passionfruit_src_folder, peaches_src_folder, pears_src_folder, pineapples_src_folder, plums_src_folder, pomegranates_src_folder, raspberries_src_folder, strawberries_src_folder, tomatoes_src_folder, watermelons_src_folder]
print(len(src_directorys))
# Out:
# 30

# %% [markdown]
# ### Plot a few random photos

# %%
from matplotlib import pyplot
from matplotlib.image import imread

acerolas_src_folder = original_dataset_path + labeldirs[0]
                
# plot first few images
for i in range(9):
    # define subplot
    pyplot.subplot(330 + 1 + i)
    # define filename
    # acerolas.0.jpg
    filename = acerolas_src_folder + 'acerolas.' + str(i) + '.jpg'
    # load image pixels
    image = imread(filename)
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# ### Copy all files from all subdirectories of original dataset folder into new dataset folder

# %%
import os
import shutil

i = 0

for subdir in range(len(src_directorys)):
    src_directory = src_directorys[i]
    i += 1
    dst_directory = new_dataset_path
    src_files = os.listdir(src_directory)

    for file_name in src_files:
        full_file_name = os.path.join(src_directory, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy(full_file_name, dst_directory)

# %% [markdown]
# Next, we can enumerate all image files in the new dataset folder and copy them into train/test class 1, class 2, class x(e.g aceloras/, apples/ or apricots/) subdirectory based on their filename.
#
# Additionally, we can randomly decide to hold back 20% of the images into the test dataset. This is done consistently by fixing the seed for the pseudorandom number generator so that we get the same split of data each time the code is run.

# %%
from random import seed
from random import random
import shutil
from shutil import copyfile

# seed random number generator
seed(1)
# define ratio of pictures to use for validation/testing
val_ratio = 0.20
# copy training/testing dataset images into subdirectories
src_directory = new_dataset_path
for file in listdir(src_directory):
    src = src_directory + '/' + file
    dst_dir = 'train/'
    if random() < val_ratio:
        dst_dir = 'test/'
    if file.startswith('acerolas'):
        dst = new_dataset_path + dst_dir + labeldirs[0] + file
        copyfile(src, dst)
    elif file.startswith('apples'):
        dst = new_dataset_path + dst_dir + labeldirs[1]+ file
        copyfile(src, dst)
    elif file.startswith('apricots'):
        dst = new_dataset_path + dst_dir + labeldirs[2] + file
        copyfile(src, dst)
    elif file.startswith('avocados'):
        dst = new_dataset_path + dst_dir + labeldirs[3] + file
        copyfile(src, dst)
    elif file.startswith('bananas'):
        dst = new_dataset_path + dst_dir + labeldirs[4] + file
        copyfile(src, dst)
    elif file.startswith('blackberries'):
        dst = new_dataset_path + dst_dir + labeldirs[5] + file
        copyfile(src, dst)
    elif file.startswith('blueberries'):
        dst = new_dataset_path + dst_dir + labeldirs[6] + file
        copyfile(src, dst)
    elif file.startswith('cantaloupes'):
        dst = new_dataset_path + dst_dir + labeldirs[7] + file
        copyfile(src, dst)    
    elif file.startswith('cherries'):
        dst = new_dataset_path + dst_dir + labeldirs[8] + file
        copyfile(src, dst)
    elif file.startswith('coconuts'):
        dst = new_dataset_path + dst_dir + labeldirs[9] + file
        copyfile(src, dst)
    elif file.startswith('figs'):
        dst = new_dataset_path + dst_dir + labeldirs[10] + file
        copyfile(src, dst)
    elif file.startswith('grapefruits'):
        dst = new_dataset_path + dst_dir + labeldirs[11] + file
        copyfile(src, dst)    
    elif file.startswith('grapes'):
        dst = new_dataset_path + dst_dir + labeldirs[12]+ file
        copyfile(src, dst)    
    elif file.startswith('guava'):
        dst = new_dataset_path + dst_dir + labeldirs[13] + file
        copyfile(src, dst)
    elif file.startswith('kiwifruit'):
        dst = new_dataset_path + dst_dir + labeldirs[14] + file
        copyfile(src, dst)
    elif file.startswith('lemons'):
        dst = new_dataset_path + dst_dir + labeldirs[15] + file
        copyfile(src, dst)    
    elif file.startswith('limes'):
        dst = new_dataset_path + dst_dir + labeldirs[16] + file
        copyfile(src, dst)
    elif file.startswith('mangos'):
        dst = new_dataset_path + dst_dir + labeldirs[17] + file
        copyfile(src, dst)    
    elif file.startswith('olives'):
        dst = new_dataset_path + dst_dir + labeldirs[18] + file
        copyfile(src, dst)    
    elif file.startswith('oranges'):
        dst = new_dataset_path + dst_dir + labeldirs[19] + file
        copyfile(src, dst)    
    elif file.startswith('passionfruit'):
        dst = new_dataset_path + dst_dir + labeldirs[20] + file
        copyfile(src, dst)    
    elif file.startswith('peaches'):
        dst = new_dataset_path + dst_dir + labeldirs[21] + file
        copyfile(src, dst)    
    elif file.startswith('pears'):
        dst = new_dataset_path + dst_dir + labeldirs[22] + file
        copyfile(src, dst)    
    elif file.startswith('pineapples'):
        dst = new_dataset_path + dst_dir + labeldirs[23] + file
        copyfile(src, dst)    
    elif file.startswith('plums'):
        dst = new_dataset_path + dst_dir + labeldirs[24] + file
        copyfile(src, dst)    
    elif file.startswith('pomegranates'):
        dst = new_dataset_path + dst_dir + labeldirs[25] + file
        copyfile(src, dst)    
    elif file.startswith('raspberries'):
        dst = new_dataset_path + dst_dir + labeldirs[26] + file
        copyfile(src, dst)    
    elif file.startswith('strawberries'):
        dst = new_dataset_path + dst_dir + labeldirs[27] + file
        copyfile(src, dst)    
    elif file.startswith('tomatoes'):
        dst = new_dataset_path + dst_dir + labeldirs[28] + file
        copyfile(src, dst)    
    elif file.startswith('watermelons'):
        dst = new_dataset_path + dst_dir + labeldirs[29] + file
        copyfile(src, dst)

# %% [markdown]
# ### Select Standardized Photo Size
#
# The photos will have to be reshaped prior to modeling so that all images have the same shape. This is often a small square image.
#
# There are many ways to achieve this, although the most common is a simple resize operation that will stretch and deform the aspect ratio of each image and force it into the new shape.
#
# We could load all photos and look at the distribution of the photo widths and heights, then design a new photo size that best reflects what we are most likely to see in practice.
#
# Smaller inputs mean a model that is faster to train, and typically this concern dominates the choice of image size.

# %% [markdown]
# ### Develop a Baseline CNN Model
#
# In this section, we will develop a baseline Convolutional Neural Network model for the FIDS30 dataset.
#
# A baseline model will establish a minimum model performance to which all of our other models can be compared, as well as a model architecture that we can use as the basis of study and improvement.
#
# We will use for starting point the general architectural principles of the VGG models. These are a good starting point because they achieved top performance in the ILSVRC 2014 competition and because the modular structure of the architecture is easy to understand and implement.
#
# The architecture involves stacking convolutional layers with small 3×3 filters followed by a max pooling layer. Together, these layers form a block, and these blocks can be repeated where the number of filters in each block is increased with the depth of the network such as 32, 64, 128, 256 for the first four blocks of the model. Padding is used on the convolutional layers to ensure the height and width shapes of the output feature maps matches the inputs.
#
# We can create a function named define_model() that will define a model and return it ready to be fit on the dataset. This function can then be customized to define different baseline models, e.g. versions of the model with 1, 2, or 3 VGG style blocks.
#
# The model will be fit with Stochastic Gradient Descent and we will start with a conservative learning rate of 0.001 and a momentum of 0.9.

# %% [markdown]
# ### One Block VGG Model
#
# The one-block VGG model has a single convolutional layer with 32 filters followed by a max pooling layer.

# %%
from datetime import datetime

# baseline model for the dataset
import sys
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

start = datetime.now()
print('Start time: ', start)

num_classes = 30

# Defining the hyperparameters
filters = 32
filtersize = (3,3)
epochs_nr = 20
batchsize = 64
input_shape = (224,224,3)
target_size = (224,224)

# define cnn model
def define_model_1_block():
    # The Sequential model is a linear stack of layers. You can also simply add layers via the .add() method.
    model = Sequential()
    # 
    model.add(Conv2D(filters, filtersize, activation='relu', kernel_initializer='he_uniform', padding='same', input_shape = input_shape))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(num_classes, activation='softmax'))
    # Compile model
    # define a loss function 
    loss_function = 'categorical_crossentropy'
    opt = SGD(lr=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss=loss_function, metrics=['accuracy'])
    model.summary()
    return model

# plot diagnostic learning curves
def summarize_diagnostics(history):
    # plot loss
    # subplot(nrows, ncols, plot_number)
    pyplot.subplot(211)
    pyplot.title('Cross Entropy Loss')
    pyplot.plot(history.history['loss'], color='blue', label='train')
    pyplot.plot(history.history['val_loss'], color='orange', label='test')
    # plot accuracy
    pyplot.subplot(212)
    pyplot.title('Classification Accuracy')
    pyplot.plot(history.history['acc'], color='blue', label='train')
    pyplot.plot(history.history['val_acc'], color='orange', label='test')
    # save plot to file
    filename = sys.argv[0].split('/')[-1]
    pyplot.savefig(filename + '_plot.png')
    pyplot.close()

# run the test harness for evaluating a model
def run_test_1_block():
    # define model
    model = define_model_1_block()
    # create data generator
    datagen = ImageDataGenerator(rescale=1.0/255.0)
    # prepare iterators
    train_it = datagen.flow_from_directory(new_dataset_path + 'train/',
        class_mode='categorical', batch_size = batchsize, target_size=target_size)
    test_it = datagen.flow_from_directory(new_dataset_path + 'test/',
        class_mode='categorical', batch_size = batchsize, target_size=target_size)
    # fit model
    history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
        validation_data=test_it, validation_steps=len(test_it), epochs = epochs_nr, verbose=0)
    # evaluate model
    _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
    print('> %.3f' % (acc * 100.0))
    # learning curves
    print('Plots...')
    summarize_diagnostics(history)
    model.save('model_1_block.h5')

# entry point, run the test harness
run_test_1_block()

stop = datetime.now()
print('Stop time: ', stop)
print('Training time: ', stop - start)
# Out:
# Start time:  2019-08-06 11:20:19.248527
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 224, 224, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 401408)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               51380352
# _________________________________________________________________
# ...

# %% [markdown]
# ### Four Block VGG Model

# %%
from datetime import datetime

# baseline model for the dataset
import sys
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator


start = datetime.now()
print('Start time: ', start)

# define cnn model
def define_model_4_block():
    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(224, 224, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(30, activation='softmax'))
    
    # compile model
    opt = SGD(lr=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# plot diagnostic learning curves
def summarize_diagnostics(history):
    # plot loss
    pyplot.subplot(211)
    pyplot.title('Cross Entropy Loss')
    pyplot.plot(history.history['loss'], color='blue', label='train')
    pyplot.plot(history.history['val_loss'], color='orange', label='test')
    # plot accuracy
    pyplot.subplot(212)
    pyplot.title('Classification Accuracy')
    pyplot.plot(history.history['acc'], color='blue', label='train')
    pyplot.plot(history.history['val_acc'], color='orange', label='test')
    # save plot to file
    filename = sys.argv[0].split('/')[-1]
    pyplot.savefig(filename + '_plot.png')
    pyplot.close()

# run the test harness for evaluating a model
def run_test_4_block():
    # define model
    model = define_model_4_block()
    # create data generator
    datagen = ImageDataGenerator(rescale=1.0/255.0)
    # prepare iterators
    train_it = datagen.flow_from_directory(new_dataset_path + 'train/',
        class_mode='categorical', batch_size=64, target_size=(224, 224))
    test_it = datagen.flow_from_directory(new_dataset_path + 'test/',
        class_mode='categorical', batch_size=64, target_size=(224, 224))
    # fit model
    history = model.fit_generator(train_it, steps_per_epoch=len(train_it), validation_data=test_it, validation_steps=len(test_it), epochs=50, verbose=0)
    # evaluate model
    _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
    print('> %.3f' % (acc * 100.0))
    # learning curves
    print('Plots...')
    summarize_diagnostics(history)
    model.save('model_4_block.h5')
    
# entry point, run the test harness
run_test_4_block()

stop = datetime.now()
print('Stop time: ', stop)
print('Training time: ', stop - start)
# Out:
# Start time:  2019-08-06 11:55:11.411759
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 224, 224, 32)      896
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 224, 224, 32)      9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 112, 112, 64)      18496
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# ...

# %% [markdown]
# ### Image Data Augmentation
#
# Image data augmentation is a technique that can be used to artificially expand the size of a training dataset by creating modified versions of images in the dataset.
#
# Training deep learning neural network models on more data can result in more skillful models, and the augmentation techniques can create variations of the images that can improve the ability of the fit models to generalize what they have learned to new images.
#
# Data augmentation can also act as a regularization technique, adding noise to the training data, and encouraging the model to learn the same features, invariant to their position in the input.
#
# Small changes to the input photos might be useful for this problem, such as small shifts and horizontal flips. These augmentations can be specified as arguments to the ImageDataGenerator used for the training dataset. The augmentations should not be used for the test dataset, as we wish to evaluate the performance of the model on the unmodified photographs.
#
# This requires that we have a separate ImageDataGenerator instance for the train and test dataset, then iterators for the train and test sets created from the respective data generators.
#
# This approach is expected to slow the rate of improvement during training and hopefully counter the overfitting of the training dataset. As such, we will increase the number of training epochs from 20 to 50 to give the model more space for refinement.

# %%
new_dataset_path = "C:/DataSets/FIDS30_30_Classes/"

# %%
from datetime import datetime
import sys
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

start = datetime.now()
print('Start time: ', start)

# define cnn model
def define_model_data_augmentation():
    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(224, 224, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(30, activation='softmax'))
    
    # compile model
    opt = SGD(lr=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# plot diagnostic learning curves
def summarize_diagnostics(history):
    # plot loss
    pyplot.subplot(211)
    pyplot.title('Cross Entropy Loss')
    pyplot.plot(history.history['loss'], color='blue', label='train')
    pyplot.plot(history.history['val_loss'], color='orange', label='test')
    # plot accuracy
    pyplot.subplot(212)
    pyplot.title('Classification Accuracy')
    pyplot.plot(history.history['acc'], color='blue', label='train')
    pyplot.plot(history.history['val_acc'], color='orange', label='test')
    # save plot to file
    filename = sys.argv[0].split('/')[-1]
    pyplot.savefig(filename + '_plot.png')
    pyplot.close()

# run the test harness for evaluating a model
def run_test_data_augmentation():
    # define model
    model = define_model_data_augmentation()
    # create data generator
    train_datagen = ImageDataGenerator(rescale=1.0/255.0, width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
    test_datagen = ImageDataGenerator(rescale=1.0/255.0)
    # prepare iterator
    train_it = train_datagen.flow_from_directory(new_dataset_path + 'train/',
        class_mode='categorical', batch_size=64, target_size=(224, 224))
    test_it = test_datagen.flow_from_directory(new_dataset_path + 'test/',
        class_mode='categorical', batch_size=64, target_size=(224, 224))
    # fit model
    history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
        validation_data=test_it, validation_steps=len(test_it), epochs=50, verbose=0)
    # evaluate model
    _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
    print('> %.3f' % (acc * 100.0))
    # learning curves
    summarize_diagnostics(history)
    model.save('model_data_augmentation.h5')

# entry point, run the test harness
run_test_data_augmentation()

stop = datetime.now()
print('Stop time: ', stop)
print('Training time: ', stop - start)
# Out:
# Start time:  2019-08-06 19:30:00.771349
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_9 (Conv2D)            (None, 224, 224, 32)      896
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 224, 224, 32)      9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 112, 112, 64)      18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# ...

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-26c82f7b558d> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 plt.plot(history.history['loss'])
#       5 plt.title('loss')
#       6 plt.ylabel('loss')
#
# NameError: name 'history' is not defined

# %% [markdown]
# ### Discussion
#
# We have explored two different models with a VGG-based architecture.
#
# The results can be summarized below, although we must assume some variance in these results given the stochastic nature of the algorithm:
#
#     VGG 1: 27.933 %
#     VGG 4: 39.665 %
#
# With one different improvements to the baseline model:
#
#     Baseline VGG4 + Data Augmentation: 53.073 %
#
# As suspected, the addition of regularization techniques slows the progression of the learning algorithms and reduces overfitting, resulting in improved performance on the holdout dataset.

# %% [markdown]
# ### Explore Transfer Learning
#
# Transfer learning involves using all or parts of a model trained on a related task.
#
# Keras provides a range of pre-trained models that can be loaded and used wholly or partially via the Keras Applications API.
#
# A useful model for transfer learning is one of the VGG models, such as VGG-16 with 16 layers that at the time it was developed, achieved top results on the ImageNet photo classification challenge.
#
# The model is comprised of two main parts, the feature extractor part of the model that is made up of VGG blocks, and the classifier part of the model that is made up of fully connected layers and the output layer.
#
# We can use the feature extraction part of the model and add a new classifier part of the model that is tailored to the our dataset. Specifically, we can hold the weights of all of the convolutional layers fixed during training, and only train new fully connected layers that will learn to interpret the features extracted from the model and make a multiclass classification.
#
# This can be achieved by loading the VGG-16 model, removing the fully connected layers from the output-end of the model, then adding the new fully connected layers to interpret the model output and make a prediction. The classifier part of the model can be removed automatically by setting the “include_top” argument to “False“, which also requires that the shape of the input also be specified for the model, in this case (224, 224, 3). This means that the loaded model ends at the last max pooling layer, after which we can manually add a flatten layer and the new clasifier layers.
#
# We will generate our training data using the Keras ImageDataGenerator.
#
# The ImageDataGenerator will make an X_training data from a directory. The sub-directory in that directory will be used as a class for each object. The image will be loaded with the RGB color mode, with the categorical class mode for the Y_training data, with a batch size of 64. Finally, shuffle the data.

# %%
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt

train_path = new_dataset_path + 'train'
test_path = new_dataset_path + 'test'

# Defining the hyperparameters
batch_size = 64
image_size = 224
num_class = 30


train_datagen = ImageDataGenerator(validation_split=0.3,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
                                directory=train_path,
                                target_size=(image_size,image_size),
                                batch_size=batch_size,
                                class_mode='categorical',
                                color_mode='rgb',
                                shuffle=True)
# Out:
# Found 792 images belonging to 30 classes.

# %% [markdown]
# Let's see our images randomly by plotting them with matplotlib

# %%
x_batch, y_batch = train_generator.next()

fig=plt.figure()
columns = 5
rows = 5
for i in range(1, columns*rows):
    num = np.random.randint(batch_size)
    image = x_batch[num].astype(np.int)
    fig.add_subplot(rows, columns, i)
    plt.imshow(image)
plt.show()

# %% [markdown]
# After that let's create our network model from VGG16 with imageNet pre-trained weight. We will freeze these layers so that the layers are not trainable to help us reduce the computation time.
#
# ### Creating our Model from VGG16
#
# As you can see below, the summary of our network model. From an input from VGG16 Layers, then we add 2 Fully Connected Layer which will extract 1024 features and an output layer that will compute the 8 classes with the softmax activation.

# %%
import keras
from keras.models import Model, load_model
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16


#Load the VGG model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))

print(base_model.summary())

    # Freeze the layers 
for layer in base_model.layers:
    layer.trainable = False
 
# # Create the model
model = keras.models.Sequential()

# # Add the vgg convolutional base model
model.add(base_model)
 
# # Add new layers
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(num_class, activation='softmax'))
 
# # Show a summary of the model. Check the number of trainable parameters    
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# ### Training

# %%
# # Compile the model
from keras.optimizers import SGD

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=1e-3),
              metrics=['accuracy'])

# # Start the training process
# model.fit(x_train, y_train, validation_split=0.30, batch_size=32, epochs=50, verbose=2)

history = model.fit_generator(
                train_generator,
                steps_per_epoch = train_generator.n/batch_size,
                epochs=10)
        
model.save('fruits_VGG16.h5')

# summarize history for accuracy
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 13/12 [===============================] - 98s 8s/step - loss: 12.1547 - acc: 0.1088
# Epoch 2/10
# 13/12 [===============================] - 89s 7s/step - loss: 8.6748 - acc: 0.2749
# Epoch 3/10
# 13/12 [===============================] - 78s 6s/step - loss: 5.7509 - acc: 0.4866
# Epoch 4/10
# 13/12 [===============================] - 94s 7s/step - loss: 4.2085 - acc: 0.5839
# Epoch 5/10
# 13/12 [===============================] - 79s 6s/step - loss: 3.3156 - acc: 0.6830
# Epoch 6/10
# 13/12 [===============================] - 31s 2s/step - loss: 2.9178 - acc: 0.7053
# Epoch 7/10
# 13/12 [===============================] - 30s 2s/step - loss: 2.0064 - acc: 0.7791
# Epoch 8/10
# 13/12 [===============================] - 30s 2s/step - loss: 1.3185 - acc: 0.8346
# Epoch 9/10
# 13/12 [===============================] - 30s 2s/step - loss: 0.9847 - acc: 0.8466
# Epoch 10/10
# 13/12 [===============================] - 30s 2s/step - loss: 0.8680 - acc: 0.8738

# %% [markdown]
# As you can see, our losses are dropped significantly and the accuracy is almost 88%.

# %%
hist = history.history
hist.keys()
# Out:
# dict_keys(['loss', 'acc'])

# %% [markdown]
# ### Testing Our Model

# %%
model = load_model('fruits_VGG16.h5')

test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
                        directory = train_path,
                        target_size = (image_size,image_size),
                        batch_size = batch_size,
                        class_mode = 'categorical',
                        color_mode = 'rgb',
                        shuffle=True)

test_generator = test_datagen.flow_from_directory(
                        directory = test_path, 
                        target_size = (image_size, image_size),
                        color_mode = 'rgb',
                        shuffle = False,
                        class_mode = 'categorical',
                        batch_size = 1)

filenames = test_generator.filenames
nb_samples = len(filenames)

fig = plt.figure()
columns = 5
rows = 5
for i in range(1, columns*rows -1):
    x_batch, y_batch = test_generator.next()

    name = model.predict(x_batch)
    name = np.argmax(name, axis=-1)
    true_name = y_batch
    true_name = np.argmax(true_name, axis=-1)

    label_map = (test_generator.class_indices)
    label_map = dict((v,k) for k,v in label_map.items()) #flip k,v
    predictions = [label_map[k] for k in name]
    true_value = [label_map[k] for k in true_name]

    image = x_batch[0].astype(np.int)
    fig.add_subplot(rows, columns, i)
    plt.title(str(predictions[0]) + ':' + str(true_value[0]))
    plt.imshow(image)
plt.show()
# Out:
# Found 792 images belonging to 30 classes.
# Found 179 images belonging to 30 classes.

# %%
new_dataset_path = "C:/DataSets/FIDS30_30_Classes/"
train_path = new_dataset_path + 'train'
test_path = new_dataset_path + 'test'

image_size = 224

# %% [markdown]
# Here's how to get the confusion matrix(or maybe statistics using scikit-learn) for all classes:
#
# 1.Predict classes

# %%
import numpy

model = load_model('fruits_VGG16.h5')

test_generator = ImageDataGenerator()

test_data_generator = test_generator.flow_from_directory(
                directory = test_path, # Put your path here
                target_size = (image_size, image_size),
                batch_size=32,
                shuffle=False)

test_steps_per_epoch = numpy.math.ceil(test_data_generator.samples / test_data_generator.batch_size)

predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)
# Get most likely class
predicted_classes = numpy.argmax(predictions, axis=1)
# Out:
# Start time:  2019-08-07 20:10:15.965324
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Found 179 images belonging to 30 classes.
# Stop time:  2019-08-07 20:10:51.909164
# Training time:  0:00:35.943840

# %%
for i in predictions:
    print(i)
# Out:
# [9.0515125e-01 2.9256422e-02 5.1542731e-05 2.6782904e-10 1.6142055e-09
#  1.5530864e-16 7.7626933e-16 3.4682064e-18 2.6174962e-06 2.8834629e-16
#  3.3479679e-14 3.9413676e-13 6.9096906e-10 1.7425976e-06 8.7472798e-12
#  5.6273167e-11 8.6585730e-12 2.1929598e-14 3.6631518e-09 1.6661248e-14
#  8.2007803e-18 6.0881155e-07 4.1097205e-11 4.3954567e-12 5.1080644e-07
#  4.7025146e-08 1.2848009e-13 2.9537647e-11 6.5535180e-02 4.9159071e-18]
# [7.5451549e-05 3.6056842e-15 1.7902482e-02 2.0293170e-12 3.5072969e-11
#  3.0765253e-08 2.7503727e-08 1.8323549e-06 2.2151269e-06 1.0909663e-11
#  2.9168865e-05 6.1458256e-09 9.7971869e-01 6.4407271e-07 2.6212821e-12
#  1.7256438e-05 2.2123892e-13 3.9062090e-14 1.8257882e-07 5.7349268e-08
#  4.2559304e-08 4.4391939e-09 6.7174365e-06 7.1432105e-08 2.6445113e-17
#  2.9446207e-07 2.2328019e-03 1.1735847e-05 1.1734430e-10 1.4665515e-07]
# [9.5305175e-01 1.8885098e-11 2.9265380e-15 2.6124150e-16 2.6271419e-19
# ...

# %% [markdown]
# 2.Get ground-truth classes and class-labels

# %%
true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())

# %% [markdown]
# 3. Use scikit-learn to get statistics

# %%
from sklearn import metrics

report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     acerolas       0.33      0.83      0.48         6
#       apples       0.43      0.50      0.46         6
#     apricots       0.33      0.25      0.29         4
#     avocados       0.80      1.00      0.89         4
#      bananas       0.78      1.00      0.88        14
# blackberries       1.00      0.50      0.67         6
#  blueberries       1.00      0.33      0.50         3
#  cantaloupes       0.67      0.57      0.62         7
#     cherries       0.71      0.50      0.59        10
#     coconuts       0.00      0.00      0.00         1
#         figs       0.75      0.75      0.75         8
#  grapefruits       0.33      0.83      0.48         6
#       grapes       0.58      1.00      0.74         7
#        guava       0.20      0.20      0.20         5
#    kiwifruit       0.83      0.71      0.77         7
#       lemons       0.29      0.50      0.36         4
# ...

# %%
from sklearn.metrics import confusion_matrix
